# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

rcParams['figure.figsize'] = '10, 4.5'

# %%
t = np.linspace(0, 10, 51)
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#         2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#         4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#         6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#         8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. ])

# %%
f = np.cos(t)

# %% [markdown]
# К сожалению, шрифты на моем ноуте все под Ubuntu, этому у вас, наверное, будет выскакивать предупреждение, что нет такого шрифта. Я просто ради теста оставил их, чтобы посмотреть как получается

# %% [markdown]
# ax = [0.5, 9.5, -2.5, 2.5]
# plt.axis(ax)
#
# Ошибка: TypeError: 'list' object is not callable
# Не знаю, в чем тут дело

# %%
title_dict = {'fontsize': 14, 'fontweight': 'bold', 'color': '#404040', 'family':'Ubuntu'}
label_dict = {'fontsize': 12, 'fontweight': 'normal', 'color': '#b0b0b0', 'family':'Noto mono'}

plt.xlim(0.5, 9.5)
plt.ylim(-2.5, 2.5)
plt.plot(t,f, color='green')
plt.title('График f(t)', fontdict=title_dict, loc='center')
plt.xlabel('Значения t', fontdict=label_dict)
plt.ylabel('Значения f', fontdict=label_dict)
plt.show()
